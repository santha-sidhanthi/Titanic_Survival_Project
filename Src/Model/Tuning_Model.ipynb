# %%
#Import Libraries


import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic_data = pd.read_pickle("C:\\Users\\santh\\Titanic_Survival_Project\\Models\\EDA.pickle")

titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
gender=pd.get_dummies(titanic_data['Sex'],drop_first=True)

titanic_data['Gender']=gender

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  Gender
# 0      0         A/5 21171   7.2500        S       1
# 1      0          PC 17599  71.2833        C       0
# 2      0  STON/O2. 3101282   7.9250        S       0
# 3      0            113803  53.1000        S       0
# ...

# %%
titanic_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked', 'Gender'],
#       dtype='object')

# %%
titanic_data.drop(['PassengerId', 'Sex', 'Name', 'Ticket'],axis=1,inplace=True)

# %%
titanic_data.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare Embarked  Gender
# 0         0       3  22.0      1      0   7.2500        S       1
# 1         1       1  38.0      1      0  71.2833        C       0
# 2         1       3  26.0      0      0   7.9250        S       0
# 3         1       1  35.0      1      0  53.1000        S       0
# 4         0       3  35.0      0      0   8.0500        S       1

# %%
titanic_data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
titanic_data['Embarked'].replace({'S':0,'C':1,'Q':2},inplace=True)

# %%
titanic_data.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Embarked  Gender
# 0         0       3  22.0      1      0   7.2500         0       1
# 1         1       1  38.0      1      0  71.2833         1       0
# 2         1       3  26.0      0      0   7.9250         0       0
# 3         1       1  35.0      1      0  53.1000         0       0
# 4         0       3  35.0      0      0   8.0500         0       1

# %%
titanic_data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#          Embarked      Gender
# count  891.000000  891.000000
# mean     0.361392    0.647587
# std      0.635673    0.477990
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    1.000000
# 75%      1.000000    1.000000
# ...

# %%
#Seperate Dependent and Independent variables

x=titanic_data[['Pclass','Age','SibSp','Parch','Fare','Embarked','Gender']]
y=titanic_data['Survived']

# %% [markdown]
# MODELLING

# %%
#import train test split method

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=40)

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predict=lr.predict(x_test)  # Predictions

# %%
import pickle

# %%
with open('Train.pickle', 'wb') as f:
    pickle.dump(titanic_data, f)

# %%
# TESTING MODEL

from sklearn.metrics import confusion_matrix
#import classification report
from sklearn.metrics import classification_report

pd.DataFrame(confusion_matrix(y_test,predict),columns=['Predicted No','Predicted Yes'],index=['Actual No','Actual Yes'])

print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84       156
#            1       0.77      0.78      0.77       112
#
#     accuracy                           0.81       268
#    macro avg       0.80      0.81      0.80       268
# weighted avg       0.81      0.81      0.81       268

# %% [markdown]
# GRIDSEARCHCV

# %%
# Grid search cross validation
from sklearn.model_selection import GridSearchCV

# %%
#from sklearn.linear_model import LogisticRegression
grid={"C":np.logspace(2,10,100),"penalty":["l1","l2"]}# l1 lasso l2 ridge
logreg=LogisticRegression()
logreg_cv=GridSearchCV(logreg,grid,cv=10)
logreg_cv.fit(x_train,y_train)
# Out:
# D:\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "D:\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "D:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ...

# %%
logreg_cv.best_params_ #this is the best parameter which our accuracy is high
# Out:
# {'C': 100.0, 'penalty': 'l2'}

# %%
GD_predictions=logreg_cv.predict(x_test)

# %%
print(classification_report(y_test,GD_predictions))  #MODEL TUNED WITH GRIDSEARCHCV
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       156
#            1       0.81      0.74      0.78       112
#
#     accuracy                           0.82       268
#    macro avg       0.82      0.81      0.81       268
# weighted avg       0.82      0.82      0.82       268

# %%
#making confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, GD_predictions)
cm
# Out:
# array([[137,  19],
#        [ 29,  83]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, GD_predictions)

# %%
accuracy #model accuracy after gridsearch
# Out:
# 0.8208955223880597

# %% [markdown]
# RANDOMIZED SEARCH CV

# %%
from sklearn.model_selection import RandomizedSearchCV
import scipy as sc

# %%
>>> from sklearn.datasets import load_iris
>>> from sklearn.linear_model import LogisticRegression
>>> from sklearn.model_selection import RandomizedSearchCV
>>> from scipy.stats import uniform
>>> iris = load_iris()
>>> logistic = LogisticRegression(solver='saga', tol=1e-2, max_iter=200,
...                               random_state=0)
>>> distributions = dict(C=uniform(loc=0, scale=4),
...                      penalty=['l2', 'l1'])
>>> clf = RandomizedSearchCV(logistic, distributions, random_state=0)
>>> search = clf.fit(x_train,y_train)
>>> search.best_params_
# Out:
# {'C': 0.22685190926977272, 'penalty': 'l2'}

# %%
rs_predictions=clf.predict(x_test)

# %%
#making confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, rs_predictions)
cm
# Out:
# array([[137,  19],
#        [ 29,  83]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, rs_predictions)      #model accuracy after randomizedsearch
accuracy
# Out:
# 0.8208955223880597

# %%
print(classification_report(y_test,rs_predictions))  #MODEL TUNED WITH RANDOMSEARCHCV
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       156
#            1       0.81      0.74      0.78       112
#
#     accuracy                           0.82       268
#    macro avg       0.82      0.81      0.81       268
# weighted avg       0.82      0.82      0.82       268

# %%
with open('Tuning_Model_version2.pickle', 'wb') as f:
    pickle.dump(titanic_data, f)

# %%
titanic_data
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare  Embarked  Gender
# 0           0       3  22.000000      1      0   7.2500         0       1
# 1           1       1  38.000000      1      0  71.2833         1       0
# 2           1       3  26.000000      0      0   7.9250         0       0
# 3           1       1  35.000000      1      0  53.1000         0       0
# 4           0       3  35.000000      0      0   8.0500         0       1
# ..        ...     ...        ...    ...    ...      ...       ...     ...
# 886         0       2  27.000000      0      0  13.0000         0       1
# 887         1       1  19.000000      0      0  30.0000         0       0
# 888         0       3  29.699118      1      2  23.4500         0       0
# 889         1       1  26.000000      0      0  30.0000         1       1
# 890         0       3  32.000000      0      0   7.7500         2       1
#
# [891 rows x 8 columns]
